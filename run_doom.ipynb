# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Ejecutar DOOM en Google Colab\n",
    "\n",
    "Este notebook permite ejecutar el clásico videojuego DOOM en Google Colab utilizando Chocolate Doom y FreeDoom."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 1,
   "metadata": {},
   "outputs": [],
   "source": [
    "!apt-get update\n",
    "!apt-get install -y xvfb\n",
    "!apt-get install -y chocolate-doom"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 2,
   "metadata": {},
   "outputs": [],
   "source": [
    "import os\n",
    "os.system('Xvfb :1 -screen 0 1024x768x16 &')\n",
    "os.environ['DISPLAY'] = ':1'"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 3,
   "metadata": {},
   "outputs": [],
   "source": [
    "!wget https://github.com/freedoom/freedoom/releases/download/v0.12.1/freedoom-0.12.1.zip\n",
    "!unzip freedoom-0.12.1.zip"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 4,
   "metadata": {},
   "outputs": [],
   "source": [
    "!chocolate-doom -iwad freedoom-0.12.1/freedoom1.wad"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 5,
   "metadata": {},
   "outputs": [],
   "source": [
    "!apt-get install -y x11vnc websockify\n",
    "!apt-get install -y novnc"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 6,
   "metadata": {},
   "outputs": [],
   "source": [
    "!x11vnc -display :1 -forever -nopw -noxdamage -shared &\n",
    "!websockify --web /usr/share/novnc/ 5901 localhost:5900 &"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 7,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "https://<your-colab-notebook-id>.vnc.googleusercontent.com/?token=<your-token>\n"
     ]
    }
   ],
   "source": [
    "from google.colab.output import eval_js\n",
    "print(eval_js(\"google.colab.kernel.proxyPort(5901)\"))"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.6.9",
   "mimetype": "text/x-python",
   "codemirror_mode": {
    "name": "ipython",
    "version": 3
   },
   "file_extension": ".py",
   "pygments_lexer": "ipython3",
   "nbconvert_exporter": "python",
   "nbformat": 4,
   "nbformat_minor": 2
  }
 }
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['# Ejecutar DOOM en Google Colab\n',
#     '\n',
#     'Este notebook permite ejecutar el clásico videojuego DOOM en Google Colab utilizando Chocolate Doom y FreeDoom.']},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {},
#    'outputs': [],
#    'source': ['!apt-get update\n',
#     '!apt-get install -y xvfb\n',
#     '!apt-get install -y chocolate-doom']},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {},
#    'outputs': [],
#    'source': ['import os\n',
#     "os.system('Xvfb :1 -screen 0 1024x768x16 &')\n",
#     "os.environ['DISPLAY'] = ':1'"]},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {},
#    'outputs': [],
#    'source': ['!wget https://github.com/freedoom/freedoom/releases/download/v0.12.1/freedoom-0.12.1.zip\n',
#     '!unzip freedoom-0.12.1.zip']},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {},
#    'outputs': [],
#    'source': ['!chocolate-doom -iwad freedoom-0.12.1/freedoom1.wad']},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {},
#    'outputs': [],
#    'source': ['!apt-get install -y x11vnc websockify\n',
#     '!apt-get install -y novnc']},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {},
#    'outputs': [],
#    'source': ['!x11vnc -display :1 -forever -nopw -noxdamage -shared &\n',
#     '!websockify --web /usr/share/novnc/ 5901 localhost:5900 &']},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {},
#    'outputs': [{'name': 'stdout',
#      'output_type': 'stream',
#      'text': ['https://<your-colab-notebook-id>.vnc.googleusercontent.com/?token=<your-token>\n']}],
#    'source': ['from google.colab.output import eval_js\n',
#     'print(eval_js("google.colab.kernel.proxyPort(5901)"))']}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.6.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'file_extension': '.py',
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'nbformat': 4,
#    'nbformat_minor': 2}}}
